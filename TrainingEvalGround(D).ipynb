# %% [markdown]
# <a href="https://colab.research.google.com/github/clearyn/PythonTraining/blob/main/TrainingEvalGround(D).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Separate Binary.PNG](data:image/png;base64,...)

# %%
# Warning: Printing unwanted or ill-formatted data to output will cause the test cases to fail

'''
# Sample code to perform I/O:

name = input()                  # Reading input from STDIN
print('Hi, %s.' % name)         # Writing output to STDOUT

'''

# Write your code here
binary = list(input())
container1 = []
container2 = []

for i in binary:
    if(i == '1'):
        container1.append(i)
    elif(i == '0'):
        container2.append(i)

s_binary = ''.join(container1 + container2)
print(s_binary)

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %%
# Warning: Printing unwanted or ill-formatted data to output will cause the test cases to fail

'''
# Sample code to perform I/O:

name = input()                  # Reading input from STDIN
print('Hi, %s.' % name)         # Writing output to STDOUT

'''

# Write your code here
listInput = list(input())
totalSpace = 0
for(i) in listInput:
    if(i == " "):
        totalSpace += 1
print(totalSpace)

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %%
# Warning: Printing unwanted or ill-formatted data to output will cause the test cases to fail

'''
# Sample code to perform I/O:

name = input()                  # Reading input from STDIN
print('Hi, %s.' % name)         # Writing output to STDOUT

'''

# Write your code here
input = input()
totalVowels = 0
for char in input:
    if char in "aiueoAIUEO":
        totalVowels += 1
print(totalVowels)

#Alternative
lowercaseInput = input.lower()
vowelsCount = {}
for vowel in 'aiueo':
    count = lowercaseInput.count(vowel)
    vowelsCount[vowel] = count
print(vowelsCount)
print(type(vowelsCount))
print(vowelsCount['a'])

# %%
def foo(x, a, b, i, j):
  k = j
  ct = 0
  while k > i - 1:
    if x[k] <= b and not (x[k] <= a):
      ct = ct + 1
    k = k -1
  return ct

x = [11,10,10,5,10,15,20,10,7,11]
print(foo(x,8,18,3,6))
print(foo(x,10,20,0,9))
print(foo(x,8,18,6,3))
print(foo(x,20,10,0,9))
print(foo(x,6,7,8,8))
# Out:
# 2
# 4
# 0
# 0
# 1

# %%
# Negative into positive
print(abs(-36))
# Check all in iterable if value is true
def all(iterable):
    for element in iterable:
        if not element:
            return False
    return True
iterable_true = [4, 5, 6]
iterable_false = [4, 5, False]
print(all(iterable_true))
print(all(iterable_false))
print(3/5)
print(3//5)
# Out:
# 36
# True
# False
# 0.6
# 0

# %%
def g(str):
  i = 0
  new_str = ""
  while i < len(str) - 1:
    new_str = new_str + str[i + 1]
    i = i + 1
  return new_str

def f(str):
  if len(str) == 0:
    return ""
  elif len(str) == 1:
    return str
  else:
    return f(g(str)) + str[0]

def h(n, str):
  while n != 1:
    if n % 2 == 0:
      n = n/2
    else:
      n = 3*n + 1
    str = f(str)
  return str

def pow(x, y):
  if y == 0:
    return 1
  else:
    return x * pow(x, y-1)

import sys
print(sys.getrecursionlimit())
print(h(1, "fruits"))
print(h(2, "fruits"))
print(h(5, "fruits"))
print(h(pow(2, 1000000000000000), "fruits"))
print(h(pow(2, 9831050005000007), "fruits"))
# Out:
# ruits
# uysa
